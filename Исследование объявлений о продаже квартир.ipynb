# %% [markdown]
# # Исследование объявлений о продаже квартир
# _____
#
# В вашем распоряжении данные сервиса Яндекс.Недвижимость — архив объявлений о продаже квартир в Санкт-Петербурге и соседних населённых пунктов за несколько лет. Нужно научиться определять рыночную стоимость объектов недвижимости. Ваша задача — установить параметры. Это позволит построить автоматизированную систему: она отследит аномалии и мошенническую деятельность.
#
# По каждой квартире на продажу доступны два вида данных. Первые вписаны пользователем, вторые — получены автоматически на основе картографических данных. Например, расстояние до центра, аэропорта, ближайшего парка и водоёма.
# _____

# %% [markdown]
# <a id=Up_start></a>
# ### Данное исследование разделим на несколько частей.
#
# ##### Часть 1. Изучение общей информации
#
# * <a href='#step_1'>Откроем файл с данными и изучим общую информацию. </a>
# * <a href='#step_1.1'>Просмотрим первые и последние 5 строк таблицы с данными</a>
# * <a href='#step_1.2'>Познакомимся с данными поближе и просмотрим числовые значения методом describe()</a>
# * <a href='#step_1.3'>А так же ознакомимся с типом данных и общей оиформацией по таблице</a>
# * <a href='#step_1_end'>Вывод</a>
#
#
# ##### Часть 2. Предобработка данных
#
# * <a href='#step_2'>Приведём формат вывода даты и времени по столбцу "first_day_exposition"  к удобному для форматирования и обработки</a>
#
# * <a href='#step_2.2'>Произведём подсчёт квартир с нулевым обозначением количества комнат в столбце "rooms"</a>
# * <a href='#step_2.3'>Проверим значения колонки "ceiling_height"</a>
# * <a href='#step_2.4'>Выполним проверку столбца "floors_total" на отсутствующие значения</a>
# * <a href='#step_2.5'>Проверм данные по столбцу "living_area"</a>
# * <a href='#step_2.6'>Исследуем столбец "kitchen_area" на предмет корректных значений</a>
# * <a href='#step_2.7'>Исследуем колонку "balcony" на предмет отсутствующих значений</a>
# * <a href='#step_2.8'>Исследуем столбец "locality_name" на предмет уникальных значений</a>
# * <a href='#step_2.9'>Просмотрим значения в столбце "airports_nearest"</a>
# * <a href='#step_2.10'>Приведём наименование столбца "cityCenters_nearest" в однотипный формат</a>
# * <a href='#step_2.11'>Проверим значения столбца "parks_around" на предмет уникальности</a>
# * <a href='#step_2.12'>Исследуем данные в колонке "parks_nearest"</a>
# * <a href='#step_2.13'>Исследуем столбец "ponds_around" на предмет отсутствующих и недостоверных данных</a>
# * <a href='#step_2.14'>Проведём исследование данных в колонке "ponds_nearest"</a>
# * <a href='#step_2.15'>Исследуем данные в колонке "days_exposition"</a>
# * <a href='#step_2.16'>Проведём исследование значений столбца "is_apartment"</a>
# * <a href='#step_2_end'>Вывод</a>
#
#
# ##### Часть 3. Посчитаем дополнительные данные и добавим их в таблицу
#
# * <a href='#step_3.1'>Посчитаем и добавим в таблицу  цену квадратного метра</a>
#     * <a href='#step_3.1.1'>Вывод </a>
# * <a href='#step_3.2'>Посчитаем и добавим в таблицу день недели, месяц и год публикации объявления</a>
#     * <a href='#step_3.1.2'>Вывод </a>
# * <a href='#step_3_3'>Посчитаем и добавим в таблицу  этаж квартиры; варианты — первый, последний, другой</a>
#     * <a href='#step_3.1.3'>Вывод </a>
# * <a href='#step_3_4'>Посчитаем и добавим в таблицу  соотношение жилой и общей площади, а также отношение площади кухни к общей</a>
#     * <a href='#step_3.1.4'>Вывод </a>
# * <a href='#step_3_end'>Вывод </a>
#
# ##### Часть 4. Проведём исследовательский анализ данных
# * <a href='#step_4'>Изучим следующие параметры: площадь, цена, число комнат, высота потолков. Построим гистограммы для каждого параметра</a>
#     * <a href='#step_4.1.1'>Площадь</a>
#     * <a href='#step_4.1.2'>Цена</a>
#     * <a href='#step_4.1.3'>Число комнат</a>
#     * <a href='#step_4.1.3'>Высота потолков</a>
#     * <a href='#step_4.1.end'>Вывод</a>
# * <a href='#step_4.2'>Изучим время продажи квартиры. Построим гистограмму. Посчитаем среднее и медиану.</a>
#     * <a href='#step_4.2.end'>Вывод</a>
# * <a href='#step_4.3'>Изучим, зависит ли цена от площади, числа комнат, удалённости от центра.</a>
#     * <a href='#step_4.3.end'>Вывод</a>
# * <a href='#step_4.4'>Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом</a>
#     * <a href='#step_4.4.end'>Вывод</a>
#
# * <a href='#step_4.5'>Также изучим зависимость цены от даты размещения: дня недели, месяца и года.</a>
#     * <a href='#step_4.5.end'>Вывод</a>
# * <a href='#step_4.6'>Выберем 10 населённых пунктов с наибольшим числом объявлений.</a>
#     * <a href='#step_4.6.end'>Вывод</a>
# * <a href='#step_4.7'>Посчитайте среднюю цену квадратного метра в этих населённых пунктах</a>
#     * <a href='#step_4.7.end'>Вывод</a>
# * <a href='#step_4.8'>Выделим среди них населённые пункты с самой высокой и низкой стоимостью жилья</a>
#     * <a href='#step_4.8.end'>Вывод</a>
# * <a href='#step_4.8.1'>Изучим предложения квартир: Выделим квартиры в Санкт-Петербурге ('locality_name'). Выясним, какая область входит в центр</a>
#     * <a href='#step_4.8.1.end'>Вывод</a>
#
# * <a href='#step_4.9'>Посчитаем среднюю цену для каждого километра</a>
# * <a href='#step_4.10'>Выделим сегмент квартир в центре и проанализируем эту территорию</a>
#     * <a href='#step_4.10.end'>Вывод</a>
# * <a href='#step_4.11'>Выделим факторы, которые влияют на стоимость квартиры </a>
#
#
# * <a href='#step_4_end'>Вывод</a>
#
# ##### Часть 5. Обший вывод по проведённому исследованию
#
# * <a href='#step_5'>Общий вывод</a>
# ___
# ___

# %% [markdown]
# <a id=step_1></a>

# %% [markdown]
# ### Часть 1. Откроем файл с данными и изучим общую информацию.

# %% [markdown]
# #### Загружаем библиотеки необходимые для работы

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# #### Установим опцию по выводу всех колонок data frame

# %%
pd.set_option('display.max_columns', None)

# %%
data = pd.read_csv('real_estate_data.csv', sep='\t')

# %% [markdown]
# <a id=step_1.1></a>

# %% [markdown]
# ##### Просмотрим первые и последние 5 строк таблицы с данными

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0  2019-03-07T00:00:00      3
# 1             7   3350000.0        40.4  2018-12-04T00:00:00      1
# 2            10   5196000.0        56.0  2015-08-20T00:00:00      2
# 3             0  64900000.0       159.0  2015-07-24T00:00:00      3
# 4             2  10000000.0       100.0  2018-06-19T00:00:00      2
#
#    ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 0            2.70          16.0         51.0      8          NaN   False
# 1             NaN          11.0         18.6      1          NaN   False
# 2             NaN           5.0         34.3      4          NaN   False
# 3             NaN          14.0          NaN      9          NaN   False
# 4            3.03          14.0         32.0     13          NaN   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data.tail()
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23694             9   9700000.0      133.81  2017-03-21T00:00:00      3
# 23695            14   3100000.0       59.00  2018-01-15T00:00:00      3
# 23696            18   2500000.0       56.70  2018-02-11T00:00:00      2
# 23697            13  11475000.0       76.75  2017-03-28T00:00:00      2
# 23698             4   1350000.0       32.30  2017-07-21T00:00:00      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 23694             3.7           5.0         73.3      3          NaN   False
# 23695             NaN           5.0         38.0      4          NaN   False
# 23696             NaN           3.0         29.7      1          NaN   False
# 23697             3.0          17.0          NaN     12          NaN   False
# 23698             2.5           5.0         12.3      1          NaN   False
#
#        open_plan  kitchen_area  balcony        locality_name  \
# ...

# %% [markdown]
# <a id=step_1.2></a>

# %% [markdown]
# ##### Познакомимся с данными поближе и просмотрим числовые значения методом describe()

# %%
data.describe().astype('int')
# Out:
#        total_images  last_price  total_area  rooms  ceiling_height  \
# count         23699       23699       23699  23699           14504
# mean              9     6541548          60      2               2
# std               5    10887013          35      1               1
# min               0       12190          12      0               1
# 25%               6     3400000          40      1               2
# 50%               9     4650000          52      2               2
# 75%              14     6800000          69      3               2
# max              50   763000000         900     19             100
#
#        floors_total  living_area  floor  kitchen_area  balcony  \
# count         23613        21796  23699         21421    12180
# mean             10           34      5            10        1
# std               6           22      4             5        1
# min               1            2      1             1        0
# ...

# %% [markdown]
# <a id=step_1.3></a>

# %% [markdown]
# ##### А так же ознакомимся с типом данных и общей оиформацией по таблице

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null object
# rooms                   23699 non-null int64
# ceiling_height          14504 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %%
data.isna().sum()
# Out:
# total_images                0
# last_price                  0
# total_area                  0
# first_day_exposition        0
# rooms                       0
# ceiling_height           9195
# floors_total               86
# living_area              1903
# floor                       0
# is_apartment            20924
# studio                      0
# open_plan                   0
# kitchen_area             2278
# balcony                 11519
# locality_name              49
# airports_nearest         5542
# cityCenters_nearest      5519
# parks_around3000         5518
# parks_nearest           15620
# ponds_around3000         5518
# ponds_nearest           14589
# days_exposition          3181
# dtype: int64

# %% [markdown]
# <a id=step_1_end></a>

# %% [markdown]
# ### Вывод

# %% [markdown]
# Судя по данным таблицы основную долю внимания придётся уделить пропущенным/отсутствующим значениям в таблице. А так же в таблице есть некоторые данные, которые сильно выбиваются из общей массы по значениям, необходимо будет ознакомиться сними по-ближе.

# %% [markdown]
# <a id=step_2></a>
# <a href='#Up_start'><k>Вернуться к оглавлению</k></a>
# ____

# %% [markdown]
# ### Часть 2. Предобработка данных

# %% [markdown]
# <a id=step_2.1></a>

# %% [markdown]
# #### Приведём формат вывода даты и времени по столбцу "first_day_exposition"  к удобному для форматирования и обработки

# %%
data['first_day_exposition'] = pd.to_datetime(data['first_day_exposition'], format='%Y-%m-%dT%H:%M:%S')

# %%
data.tail(2)
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 23697             3.0          17.0          NaN     12          NaN   False
# 23698             2.5           5.0         12.3      1          NaN   False
#
#        open_plan  kitchen_area  balcony        locality_name  \
# 23697      False          23.3      2.0      Санкт-Петербург
# 23698      False           9.0      NaN  поселок Новый Учхоз
#
#        airports_nearest  cityCenters_nearest  parks_around3000  parks_nearest  \
# 23697           39140.0              10364.0               2.0          173.0
# 23698               NaN                  NaN               NaN            NaN
#
#        ponds_around3000  ponds_nearest  days_exposition
# ...

# %% [markdown]
# <a id=step_2.2></a>

# %% [markdown]
# #### Произведём подсчёт квартир с нулевым обозначением количества комнат  в столбце "rooms"

# %%
data.query('rooms == 0')['rooms'].count()
# Out:
# 197

# %% [markdown]
# проверим по таблице, к каким данныи относятся 0 комнат

# %%
data.query('rooms == 0').head(10)
# Out:
#      total_images  last_price  total_area first_day_exposition  rooms  \
# 144             1   2450000.0       27.00           2017-03-30      0
# 349             4   2320000.0       25.00           2017-09-27      0
# 440             8   2480000.0       27.11           2018-03-12      0
# 508             0   3375000.0       34.40           2017-03-28      0
# 608             2   1850000.0       25.00           2019-02-20      0
# 697            12   2500000.0       24.10           2017-12-01      0
# 716             5   1500000.0       17.00           2017-06-07      0
# 780             9   2600000.0       26.10           2018-02-20      0
# 839            14   1900000.0       35.00           2017-04-14      0
# 946             5   2200000.0       23.00           2016-09-27      0
#
#      ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 144             NaN          24.0        15.50      2          NaN    True
# ...

# %% [markdown]
# Логично предположить, что с такой площадью и отсутствием площади кухни, 0 комнат означает, что это квартиры-студии.
# В стаком случае отсавим всё как есть, здесь ошибок в указании данных нет.

# %% [markdown]
# <a id=step_2.3></a>

# %% [markdown]
# #### Проверим значения колонки "ceiling_height"

# %% [markdown]
# Для начала вычислим среднее значение по высоте потолков ограничив выборку предельно-допустимыми значениями

# %%
data.query('ceiling_height > 2 and ceiling_height < 8.3')['ceiling_height'].mean()
# Out:
# 2.728440956858407

# %% [markdown]
# Приравняем невошедшие значения к среднему, т.к. потолков выше 8,3 м. и ниже 2 м. быть не может

# %%
data.loc[data['ceiling_height'] < 2, 'ceiling_height'] = 2.72

# %%
data.loc[data['ceiling_height'] > 8.3, 'ceiling_height'] = 2.72

# %% [markdown]
# Проверяем результат:

# %%
data.query('ceiling_height < 2 and ceiling_height > 8.3')['ceiling_height'].sum()
# Out:
# 0.0

# %% [markdown]
# Отлично, теперь заполним отсутствующие значения в столбце средней величиной, для сохранения статистики по остальным данным в других столбцах

# %%
data['ceiling_height'] = data['ceiling_height'].fillna(2.72)

# %% [markdown]
# Провверим результат

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          23699 non-null float64
# floors_total            23613 non-null float64
# living_area             21796 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            21421 non-null float64
# balcony                 12180 non-null float64
# locality_name           23650 non-null object
# airports_nearest        18157 non-null float64
# cityCenters_nearest     18180 non-null float64
# parks_around3000        18181 non-null float64
# ...

# %% [markdown]
# <a id=step_2.4></a>

# %% [markdown]
# #### Выполним проверку столбца "floors_total" на отсутствующие значения

# %%
data.loc[data['floors_total'].isna()].head(10)
# Out:
#       total_images  last_price  total_area first_day_exposition  rooms  \
# 186             12  11640000.0       65.20           2018-10-02      2
# 237              4   2438033.0       28.10           2016-11-23      1
# 457              4   9788348.0       70.80           2015-08-01      2
# 671              4   6051191.0       93.60           2017-04-06      3
# 1757             5   3600000.0       39.00           2017-04-22      1
# 1930             1   9750000.0       66.77           2016-05-13      2
# 2392             7   5395770.0       53.00           2017-06-29      2
# 2846             4   2325000.0       27.80           2016-09-21      1
# 2952            10   6500000.0       54.30           2019-04-23      1
# 3031             9   6400000.0       56.70           2018-03-27      2
#
#       ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 186             2.72           NaN        30.80      4          NaN   False
# ...

# %%
data['floors_total'].isna().sum()
# Out:
# 86

# %% [markdown]
# Из данной выборки видно только то, что невозможно по остальным праметрам однозначно сказать об этажности дома. По-этому оставим эти данные пока без изменений.

# %% [markdown]
# <a id=step_2.5></a>

# %% [markdown]
# #### Проверм данные по столбцу "living_area"

# %%
data['living_area'].agg(['min','max','mean','median'])
# Out:
# min         2.000000
# max       409.700000
# mean       34.457852
# median     30.000000
# Name: living_area, dtype: float64

# %% [markdown]
# Выведем данные для визульного ознаколения, для каких квартир указаны такие значения по жилой площади:

# %%
data.query('living_area < 5')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 3242              7   4440000.0        41.0           2017-07-02      1
# 13915            20   6350000.0        52.0           2018-02-06      2
# 21758             0   2330000.0        23.0           2018-01-01      0
# 23574            14  64990000.0       139.0           2015-11-24      3
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 3242             2.72          17.0          3.0     17          NaN   False
# 13915            3.00           6.0          2.0      2          NaN   False
# 21758            2.72          24.0          2.0     22          NaN    True
# 23574            3.00           8.0          3.0      8          NaN   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 3242       False          11.0      NaN  Санкт-Петербург           19272.0
# ...

# %% [markdown]
# Однозначно определить какое значение следует указать мы не можем, но ясно одно, что остальной массив даннх лучше сохранить, по-этому заменим неправдоподобные значения на None

# %%
data.loc[data['living_area'] < 5, 'living_area'] = None

# %%
data['living_area'].isna().sum()
# Out:
# 1907

# %% [markdown]
# проверим результат применения None к выбранным строкам:

# %%
data.query('living_area < 5')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []

# %% [markdown]
# Отлично, неправдоподобные данные по площади жилого помещения устранены. К сожалению таких пропущенных значений в столбце много, но удалять строки с другими данными вредно для статистики, оставим строки с неизвестными площадями как есть.

# %% [markdown]
# <a id=step_2.6></a>

# %% [markdown]
# #### Исследуем столбец "kitchen_area" на предмет корректных значений

# %% [markdown]
# Согласно Снип, кухня не может быть менее 5 м2. Выполним выборку по данному значению:

# %%
data.query('kitchen_area < 5')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 76               12   2800000.0        55.1           2016-05-14      3
# 298               9   2650000.0        42.8           2017-04-25      2
# 422               8   1700000.0        55.2           2018-03-24      3
# 906              15   2600000.0        27.0           2017-07-10      1
# 1327              6   2650000.0        46.2           2016-12-01      2
# ...             ...         ...         ...                  ...    ...
# 22839            14   3350000.0        27.0           2018-11-03      1
# 22849             6   2380000.0        25.0           2016-03-22      1
# 23110             1   2900000.0        34.0           2018-02-01      2
# 23498             7   1600000.0        54.0           2016-12-26      2
# 23678            10   3500000.0        43.0           2016-05-19      2
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
data['kitchen_area'].isna().sum()
# Out:
# 2278

# %% [markdown]
# Заполним пропуски в значениях нулевыми учитывая, что отсутствие данных о площади кухни связано с квартирами, где комнаты объеденины с кухней и площадь комнаты уже учитывает площадь кухни.

# %%
data['kitchen_area'] = data['kitchen_area'].fillna(0)

# %% [markdown]
# Вычислим среднее значение для кухни отсортировав "мусорные" значения

# %%
MEAN_AREA = data.query('kitchen_area > 5' and 'kitchen_area < 15')['kitchen_area'].mean()

# %% [markdown]
# Заменим ошибочные данные средним значением нашей выборки

# %%
data.loc[data['kitchen_area'] < 5, 'kitchen_area'] = MEAN_AREA

# %% [markdown]
# Проверяем результат:

# %%
data.query('kitchen_area < 5')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []

# %% [markdown]
# <a id=step_2.7></a>

# %% [markdown]
# #### Исследуем колонку "balcony" на предмет отсутствующих значений

# %%
data['balcony'].isna().sum()
# Out:
# 11519

# %% [markdown]
# Ого, пропусков около 50% от всех данных, это говорит о том, что такие пропуски не могут быть случайны, ознакомимся со смежными данными по отсутствующим значениям колонки "balcony"

# %%
data.loc[data['balcony'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# 5                10   2890000.0       30.40           2018-09-10      1
# 8                20   2900000.0       33.16           2018-05-23      1
# 10                5   5050000.0       39.60           2017-11-16      1
# ...             ...         ...         ...                  ...    ...
# 23692             2   1350000.0       30.00           2017-07-07      1
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
# Судя по распределению данных, логично было бы предположить, что те данные которые имеют пропуск - это означает отсутствие балкона, таким образом можем указать 0 вместо NaN

# %%
data['balcony']=data['balcony'].fillna(0).astype('int')

# %% [markdown]
# Проверяем результат удаления NaN значений

# %%
data['balcony'].isna().sum()
# Out:
# 0

# %% [markdown]
# <a id=step_2.8></a>

# %% [markdown]
# #### Исследуем столбец "locality_name"  на предмет уникальных значений

# %%
data['locality_name'].unique()
# Out:
# array(['Санкт-Петербург', 'посёлок Шушары', 'городской посёлок Янино-1',
#        'посёлок Парголово', 'посёлок Мурино', 'Ломоносов', 'Сертолово',
#        'Петергоф', 'Пушкин', 'деревня Кудрово', 'Коммунар', 'Колпино',
#        'поселок городского типа Красный Бор', 'Гатчина', 'поселок Мурино',
#        'деревня Фёдоровское', 'Выборг', 'Кронштадт', 'Кировск',
#        'деревня Новое Девяткино', 'посёлок Металлострой',
#        'посёлок городского типа Лебяжье',
#        'посёлок городского типа Сиверский', 'поселок Молодцово',
#        'поселок городского типа Кузьмоловский',
#        'садовое товарищество Новая Ропша', 'Павловск',
#        'деревня Пикколово', 'Всеволожск', 'Волхов', 'Кингисепп',
#        'Приозерск', 'Сестрорецк', 'деревня Куттузи', 'посёлок Аннино',
#        'поселок городского типа Ефимовский', 'посёлок Плодовое',
#        'деревня Заклинье', 'поселок Торковичи', 'поселок Первомайское',
# ...

# %%
data['locality_name'].value_counts().tail(20)
# Out:
# поселок Володарское                    1
# коттеджный поселок Счастье             1
# деревня Пустынка                       1
# деревня Зимитицы                       1
# поселок Коробицыно                     1
# коттеджный поселок Кивеннапа Север     1
# село Никольское                        1
# посёлок Коробицыно                     1
# посёлок городского типа Рябово         1
# поселок Тёсово-4                       1
# поселок городского типа Кондратьево    1
# деревня Пикколово                      1
# деревня Нижняя                         1
# деревня Куровицы                       1
# садовое товарищество Садко             1
# посёлок Алексеевка                     1
# деревня Большой Сабск                  1
# деревня Новолисино                     1
# посёлок Дзержинского                   1
# деревня Щеглово                        1
# Name: locality_name, dtype: int64

# %% [markdown]
# Приведём значения к нижнему регистру для избавления от дубликатов

# %%
data['locality_name'] = data['locality_name'].str.lower()

# %%
data['locality_name'].duplicated().sum()
# Out:
# 23334

# %% [markdown]
# Выполним замену ошибки в написании 'поселок' вместо 'посёлок':

# %%
data['locality_name'] = data['locality_name'].str.replace('поселок','посёлок')

# %% [markdown]
# Проверяем результат

# %%
data['locality_name'].unique()
# Out:
# array(['санкт-петербург', 'посёлок шушары', 'городской посёлок янино-1',
#        'посёлок парголово', 'посёлок мурино', 'ломоносов', 'сертолово',
#        'петергоф', 'пушкин', 'деревня кудрово', 'коммунар', 'колпино',
#        'посёлок городского типа красный бор', 'гатчина',
#        'деревня фёдоровское', 'выборг', 'кронштадт', 'кировск',
#        'деревня новое девяткино', 'посёлок металлострой',
#        'посёлок городского типа лебяжье',
#        'посёлок городского типа сиверский', 'посёлок молодцово',
#        'посёлок городского типа кузьмоловский',
#        'садовое товарищество новая ропша', 'павловск',
#        'деревня пикколово', 'всеволожск', 'волхов', 'кингисепп',
#        'приозерск', 'сестрорецк', 'деревня куттузи', 'посёлок аннино',
#        'посёлок городского типа ефимовский', 'посёлок плодовое',
#        'деревня заклинье', 'посёлок торковичи', 'посёлок первомайское',
#        'красное село', 'посёлок понтонный', 'сясьстрой', 'деревня старая',
# ...

# %% [markdown]
# Отлично, теперь порядок. Довольно распространённая ошибка с применением буквы "ё" в тексте, а так же использование разного регистра букв, это чисто человеческий фактор возникновения ошибки.

# %% [markdown]
# <a id=step_2.9></a>

# %% [markdown]
# #### Просмотрим значения в столбце "airports_nearest"

# %% [markdown]
# выведем значения равные 0 для оценки ошибки в выгрузке данных

# %%
data.query('airports_nearest == 0')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 21085             0   7000000.0        34.7           2018-09-23      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# 21085             2.7           9.0         19.8      3          NaN   False
#
#        open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# 21085      False           6.0        2  санкт-петербург               0.0
#
#        cityCenters_nearest  parks_around3000  parks_nearest  ponds_around3000  \
# 21085              22801.0               0.0            NaN               0.0
#
#        ponds_nearest  days_exposition
# 21085            NaN             60.0

# %% [markdown]
# Оценка показала, что единичное значение вызвано скорей всего ошибкой в выгрузке данных, приравняем значения к None, т.к. мы не можем по смежным данным определить расстояние до объекта в м.

# %%
data.loc[data['airports_nearest'] == 0, 'airports_nearest'] = None

# %% [markdown]
# проверим результат:

# %%
data.query('airports_nearest == 0')
# Out:
# Empty DataFrame
# Columns: [total_images, last_price, total_area, first_day_exposition, rooms, ceiling_height, floors_total, living_area, floor, is_apartment, studio, open_plan, kitchen_area, balcony, locality_name, airports_nearest, cityCenters_nearest, parks_around3000, parks_nearest, ponds_around3000, ponds_nearest, days_exposition]
# Index: []

# %%
data['airports_nearest'].min()
# Out:
# 6450.0

# %% [markdown]
# Отлично, ближайшая квартира в 6,5 км. от аэропорта

# %% [markdown]
# <a id=step_2.10></a>

# %% [markdown]
# #### Приведём наименование столбца "cityCenters_nearest" в однотипный формат

# %%
data.rename(columns = {'cityCenters_nearest':'city_centers_nearest'}, inplace=True)

# %% [markdown]
# приведём так же наименования столбцов "parks_around3000" и "ponds_around3000" к привычно читаемому однотипу

# %%
data.rename(columns = {'parks_around3000':'parks_around', 'ponds_around3000':'ponds_around'}, inplace=True)

# %%
data.columns
# Out:
# Index(['total_images', 'last_price', 'total_area', 'first_day_exposition',
#        'rooms', 'ceiling_height', 'floors_total', 'living_area', 'floor',
#        'is_apartment', 'studio', 'open_plan', 'kitchen_area', 'balcony',
#        'locality_name', 'airports_nearest', 'city_centers_nearest',
#        'parks_around', 'parks_nearest', 'ponds_around', 'ponds_nearest',
#        'days_exposition'],
#       dtype='object')

# %% [markdown]
# С наименованием стобцов теперь всё в порядке, переходим к данным

# %% [markdown]
# <a id=step_2.11></a>

# %% [markdown]
# #### Проверим значения столбца "parks_around" на предмет уникальности

# %%
data['parks_around'].unique()
# Out:
# array([ 1.,  0.,  2., nan,  3.])

# %%
data['parks_around'].isna().sum()
# Out:
# 5518

# %% [markdown]
# Очевидно, что отсутствующие значения означают, что парков по близости 3 км. нет, заменим их на нулевое значение и изменим тип данных на целочисленный.

# %%
data['parks_around'] = data['parks_around'].fillna(0).astype('int')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 23699 entries, 0 to 23698
# Data columns (total 22 columns):
# total_images            23699 non-null int64
# last_price              23699 non-null float64
# total_area              23699 non-null float64
# first_day_exposition    23699 non-null datetime64[ns]
# rooms                   23699 non-null int64
# ceiling_height          23699 non-null float64
# floors_total            23613 non-null float64
# living_area             21792 non-null float64
# floor                   23699 non-null int64
# is_apartment            2775 non-null object
# studio                  23699 non-null bool
# open_plan               23699 non-null bool
# kitchen_area            23699 non-null float64
# balcony                 23699 non-null int64
# locality_name           23650 non-null object
# airports_nearest        18156 non-null float64
# city_centers_nearest    18180 non-null float64
# parks_around            23699 non-null int64
# ...

# %%
data['parks_around'].agg(['min','max'])
# Out:
# min    0
# max    3
# Name: parks_around, dtype: int64

# %%
data.query('parks_around == 0').count()
# Out:
# total_images            15624
# last_price              15624
# total_area              15624
# first_day_exposition    15624
# rooms                   15624
# ceiling_height          15624
# floors_total            15572
# living_area             14295
# floor                   15624
# is_apartment             1828
# studio                  15624
# open_plan               15624
# kitchen_area            15624
# balcony                 15624
# locality_name           15590
# airports_nearest        10101
# city_centers_nearest    10106
# parks_around            15624
# parks_nearest               4
# ponds_around            10106
# ponds_nearest            4290
# days_exposition         13588
# dtype: int64

# %% [markdown]
# <a id=step_2.12></a>

# %% [markdown]
# #### Исследуем данные в колонке "parks_nearest"

# %%
data['parks_nearest'].agg(['min','max','mean','median'])
# Out:
# min          1.000000
# max       3190.000000
# mean       490.804555
# median     455.000000
# Name: parks_nearest, dtype: float64

# %%
data['parks_nearest'].isna().sum()
# Out:
# 15620

# %%
mean_data_parks=data.query('parks_nearest > 3000')['parks_nearest'].mean()

# %% [markdown]
# Такое количество отсутствующих значений по приближённости парка говорят о том, что необходимо проверить наличие проблемы в выгрузке данных из программы, т.к. по столбцу о количестве парков на расстоянии 3 км. значения заполнены. Учитывая, что количество парков, которые находятся на большем расстоянии чем 3км, соответствуюет количеству пропущенных значений, логично будет произвести замену отсутствующих данных на среднюю величину удалённости до парка свше 3км.

# %%
data['parks_nearest']=data['parks_nearest'].fillna(mean_data_parks)

# %% [markdown]
# <a id=step_2.13></a>

# %% [markdown]
# #### Исследуем столбец "ponds_around" на предмет отсутствующих и недостоверных данных.

# %%
data['ponds_around'].agg(['min','max','median'])
# Out:
# min       0.0
# max       3.0
# median    1.0
# Name: ponds_around, dtype: float64

# %%
data['ponds_around'].isna().sum()
# Out:
# 5518

# %% [markdown]
# Выполним замену отсутствующих значений на "0", т.к. отсутствие данных, вероятнее всего означает что на расстоянии 3км водоёмов нет. Дополнительно изменим тип данных на целочисленный.

# %%
data['ponds_around'] = data['ponds_around'].fillna(0).astype('int')

# %% [markdown]
# <a id=step_2.14></a>

# %% [markdown]
# #### Проведём исследование данных в колонке "ponds_nearest"

# %%
data['ponds_nearest'].agg(['min','max','median'])
# Out:
# min         13.0
# max       1344.0
# median     502.0
# Name: ponds_nearest, dtype: float64

# %%
data['ponds_nearest'].isna().sum()
# Out:
# 14589

# %% [markdown]
# больше половины данных не имеют значений, это означает, что водоёмов по близости 3км нет и такие данные заполнять какими-либо значениями не логично.

# %% [markdown]
# <a id=step_2.15></a>

# %% [markdown]
# ####  Исследуем данные в колонке "days_exposition"

# %%
data['days_exposition'].agg(['min','max','median'])
# Out:
# min          1.0
# max       1580.0
# median      95.0
# Name: days_exposition, dtype: float64

# %%
data['days_exposition'].isna().sum()
# Out:
# 3181

# %%
data.query('days_exposition == "NaN"')
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 7                 5   7915000.0       71.60           2019-04-18      2
# 44               13   5350000.0       40.00           2018-11-18      1
# 45               17   5200000.0       50.60           2018-12-02      2
# 46               17   6600000.0       52.10           2019-01-31      2
# ...             ...         ...         ...                  ...    ...
# 23684            20  21400000.0      145.00           2018-11-02      4
# 23685            15   2490000.0       31.00           2019-01-24      1
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %% [markdown]
# Из приведённых выше данных можно сделать вывод, что объявления были размещены, но пропущенне значения в столбце "days_exposition" означают, что до сих пор объявление актульно и не снято с пуликации.

# %% [markdown]
# <a id=step_2.16></a>

# %% [markdown]
# #### Проведём исследование значений столбца "is_apartment"

# %%
data['is_apartment'].unique()
# Out:
# array([nan, False, True], dtype=object)

# %% [markdown]
# Выведем данные для ознакомеления

# %%
data.loc[data['is_apartment'].isna()]
# Out:
#        total_images  last_price  total_area first_day_exposition  rooms  \
# 0                20  13000000.0      108.00           2019-03-07      3
# 1                 7   3350000.0       40.40           2018-12-04      1
# 2                10   5196000.0       56.00           2015-08-20      2
# 3                 0  64900000.0      159.00           2015-07-24      3
# 4                 2  10000000.0      100.00           2018-06-19      2
# ...             ...         ...         ...                  ...    ...
# 23694             9   9700000.0      133.81           2017-03-21      3
# 23695            14   3100000.0       59.00           2018-01-15      3
# 23696            18   2500000.0       56.70           2018-02-11      2
# 23697            13  11475000.0       76.75           2017-03-28      2
# 23698             4   1350000.0       32.30           2017-07-21      1
#
#        ceiling_height  floors_total  living_area  floor is_apartment  studio  \
# ...

# %%
data.query('is_apartment != True or is_apartment != False')['is_apartment'].count()
# Out:
# 2775

# %% [markdown]
# Ввиду того, что пропущенные значения скорей всего означают,что аппартаменты не входят в предложение по продаже кваритр - выполним замену неизвестных данных на значение <b>False</b> и приведём тип данных в <b>bool</b>

# %%
data['is_apartment'] = data['is_apartment'].fillna(False)

# %% [markdown]
# Проверим результат

# %%
data['is_apartment'].unique()
# Out:
# array([False,  True])

# %% [markdown]
# Выведем таблицу для ознакомления с данными после выполнения преобразований

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %% [markdown]
# <a id=step_2_end></a>

# %% [markdown]
# ### Вывод

# %% [markdown]
# По результату проведённой обработки данных, можно сказать что довольно большая часть данных, которая может влиять на итоговую статистику, а так же на решение о прибретении квартир, потеряна при выгрузке таблицы либо отсутствует. Об этом обязательно необходимо сообщить ответственным сотрудникам по выгрузке и сбору данных.

# %% [markdown]
# <a id=step_3></a>
# <a href='#Up_start'><k>Вернуться к оглавлению</k></a>
# ____

# %% [markdown]
# ### Часть 3. Посчитаем дополнительные данные и добавим их в таблицу

# %% [markdown]
# <a id=step_3.1></a>

# %% [markdown]
# #### Посчитаем и добавим в таблицу  цену квадратного метра

# %% [markdown]
# Доолнительный столбец назовём 'price_per_square_meter'

# %%
data['price_per_square_meter'] = data['last_price']/data['total_area']

# %%
data['price_per_square_meter'] = data['price_per_square_meter'].astype('int')

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['price_per_square_meter'].mean().round(1)
# Out:
# 99421.2

# %% [markdown]
# <a id=step_3.1.1></a>

# %% [markdown]
# #### Вывод

# %% [markdown]
# При довольно сильном разбросе цен предложений квартир, средняя цена за кв.метр составляет 100 тыс.руб

# %% [markdown]
# <a id=step_3.2></a>

# %% [markdown]
# ####  Посчитаем и добавим в таблицу день недели, месяц и год публикации объявления

# %% [markdown]
# Новый столбец назовём 'day_of_week_exposition'

# %%
data['day_of_week_exposition']= data['first_day_exposition'].dt.weekday

# %%
data['month_exposition']=data['first_day_exposition'].dt.month

# %%
data['years_exposition']=data['first_day_exposition'].dt.year

# %% [markdown]
# Проверим результат

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['years_exposition'].value_counts()
# Out:
# 2018    8519
# 2017    8190
# 2019    2879
# 2016    2783
# 2015    1191
# 2014     137
# Name: years_exposition, dtype: int64

# %% [markdown]
# <a id=step_3.1.2></a>

# %% [markdown]
# #### Вывод

# %% [markdown]
# Очевидно, что количество предложений на рынке недвижимости было пиковым значением в 2017 и 2018 годах, а вот в 2019 количество предложений сократилось в 4 раза и вернулось на уровень 2016 года

# %% [markdown]
# <a id=step_3_3></a>

# %% [markdown]
# #### Разделим на группы этажи квартир и добавим их в таблицу; варианты — первый, последний, другой

# %% [markdown]
# Новый столбец назовём 'group'

# %%
last_floor = data.query('floors_total/floor == 1')

# %%
data['group'] = data['floor']

# %%
data.loc[data['group'] == 1, 'group'] = 'Первый'

# %%
data.loc[last_floor.index, 'group'] = 'Последний'

# %%
data.loc[(data['group'] != 'Первый') & (data['group']!='Последний'), 'group'] = 'Другой'

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['group'].value_counts()
# Out:
# Другой       17446
# Последний     3361
# Первый        2892
# Name: group, dtype: int64

# %% [markdown]
# <a id=step_3.1.3></a>

# %% [markdown]
# #### Вывод

# %% [markdown]
# Судя по количеству предложений, более актуальны квартиры на любом этаже кроме первого и последнего

# %% [markdown]
# <a id=step_3_4></a>

# %% [markdown]
# ####  Посчитаем и добавим в таблицу  соотношение жилой и общей площади, а также отношение площади кухни к общей

# %%
data['attitude_liv/total']=(data['living_area']/data['total_area']).round(2)

# %%
data['attitude_kitch/total']=(data['kitchen_area']/data['total_area']).round(2)

# %% [markdown]
# Проверим результат

# %%
data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
data['attitude_liv/total'].mean().round(2)
# Out:
# 0.56

# %%
data['attitude_kitch/total'].mean().round(2)
# Out:
# 0.19

# %% [markdown]
# <a id=step_3.1.4></a>

# %% [markdown]
# #### Вывод

# %% [markdown]
# По среднестатисическим данным площадь кухни занимает практически 20% от общей площади, а жилая площадь только половину, это говорит о том, что в основном в продаже 1-2 комнатные квартиры с небольшой кухней.

# %% [markdown]
# <a id=step_3_end></a>

# %% [markdown]
# ### Вывод

# %% [markdown]
# По результату проведённого анализа нелья не заметить, что активные продажи жилья начались с 2017 года, а предложения первого и последнего этажей в сумме по количеству объявлений уступает любому другому больше чем в три раза от всего количества объявлений. В среднем жилая площадь предложенных квартир знимает всего половину от общей площади, в то время как площадь кухни доходит до 20% от общей площади. И при всём при этом средняя цена за кв.метр достигает 100 тыс.руб.

# %% [markdown]
# <a id=step_4></a>
# <a href='#Up_start'><k>Вернуться к оглавлению</k></a>
# ____

# %% [markdown]
# ### Часть 4. Проведём исследовательский анализ данных

# %% [markdown]
# #### Изучим следующие параметры: площадь, цена, число комнат, высота потолков. Построим гистограммы для каждого параметра

# %% [markdown]
# <a id=step_4.1.1></a>

# %% [markdown]
# ###### Площадь:

# %%
print('Диаграмма размаха площади квартиры')
data.boxplot(column=['total_area'], figsize=(10,5), grid=True)
plt.ylabel('Площадь квартиры в метрах')
plt.show()
# Out:
# Диаграмма размаха площади квартиры

# %%
data['total_area'].describe()
# Out:
# count    23699.000000
# mean        60.348651
# std         35.654083
# min         12.000000
# 25%         40.000000
# 50%         52.000000
# 75%         69.900000
# max        900.000000
# Name: total_area, dtype: float64

# %% [markdown]
# Отсечём чрезмерно выбивающиеся значения согласно распределению данных ящика с усами, площадь свыше 100 кв.метров нам для дальнейшей статистики не интересна.

# %%
good_data = data.query('total_area < 100')

# %%
print('Диаграмма размаха площади квартиры после отсечения выбивающихся значений')
good_data.boxplot(column=['total_area'], figsize=(9,5), grid=True)
plt.ylabel('площадь квартиры в квадратных метрах')
plt.show()
# Out:
# Диаграмма размаха площади квартиры после отсечения выбивающихся значений

# %% [markdown]
# Построим гистограмму

# %%
import numpy as np
from matplotlib import pyplot as plt

# %%
good_data.sort_values(by='total_area', ascending=True).plot(kind='hist', y='total_area',title='Распределение предложений квартир по площади',bins=100, figsize=(15,5), grid=True)

plt.xlabel('Площадь квартиры в кв.метрах')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# <a id=step_4.1.2></a>

# %% [markdown]
# ##### Цена

# %%
print('Диаграмма размаха цены предложений')
good_data.boxplot('last_price')
plt.ylabel('цена на момент снятия с публикации')
plt.show()
# Out:
# Диаграмма размаха цены предложений

# %% [markdown]
# Отбросим выбивающиеся значения по цене, т.к. они будут мешать при построении графика, а так же усложнят анализ и прочтение данных с гистограммы. Очевидно, что стоимость квартир свыше 9 млн. встречается редко в наших данных, отсечём лишнее.

# %%
good_data = good_data.query('last_price < 9000000')

# %%
good_data.plot(kind='hist', y='last_price', title='Распределение предложений квартир по цене',grid=True, bins=50, figsize=(15,5))
plt.ylabel('количество предложений')
plt.xlabel('цена на момент снятия с публикации')
plt.show()

# %% [markdown]
# Из графика хорошо виден ценовой сегмент квартир в районе 4 млн.руб

# %% [markdown]
# <a id=step_4.1.3></a>

# %% [markdown]
# ###### Число комнат

# %%
good_data.plot(kind='hist',y='rooms',title='Распределение предложений по количеству комнат',grid=True, bins=50, figsize=(5,8))
plt.xlabel('Количество комнат')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# <a id=step_4.1.4></a>

# %% [markdown]
# ##### Высота потолков

# %%
print('Диаграмма размаха высоты потолков')
good_data.boxplot(column=['ceiling_height'], figsize=(8,5), grid=True)

plt.ylabel('Высота потолков')
plt.show()
# Out:
# Диаграмма размаха высоты потолков

# %% [markdown]
# Основываясь на графике "ящика с усами", отсечём квартиры с потолками свыше 2,9 метра, а так же ниже 2,4

# %%
good_data = good_data.query('ceiling_height < 2.9 and ceiling_height > 2.4')
good_data.plot(kind='hist',y='ceiling_height',grid=True, bins=10, figsize=(10,5),title='Распределение предложений по высоте потолков')
plt.xlabel('Высота потолоков')
plt.ylabel('Количество предложений')
plt.show()

# %% [markdown]
# <a id=step_4.1.end></a>
# #### Вывод

# %% [markdown]
# По результату проведённого анализа  площади, цены, числа комнат и высоты потолков, однозначно можно сказать, что подавляющее большинство объявлений о продаже квартир составляют 1-2 комнатные квартиры в ценовом диапазоне 4 млн.руб и высотой потолков в 2,75 метра

# %% [markdown]
# <a id=step_4.2></a>

# %% [markdown]
# #### Изучим время продажи квартиры. Построим гистограмму. Посчитаем среднее и медиану.

# %% [markdown]
# Опишите, сколько обычно занимает продажа. Когда можно считать, что продажи прошли очень быстро, а когда необычно долго?

# %%
good_data.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 1             7   3350000.0        40.4           2018-12-04      1
# 2            10   5196000.0        56.0           2015-08-20      2
# 5            10   2890000.0        30.4           2018-09-10      1
# 6             6   3700000.0        37.3           2017-11-02      1
# 7             5   7915000.0        71.6           2019-04-18      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 1            2.72          11.0         18.6      1         False   False
# 2            2.72           5.0         34.3      4         False   False
# 5            2.72          12.0         14.4      5         False   False
# 6            2.72          26.0         10.6      6         False   False
# 7            2.72          24.0          NaN     22         False   False
#
#    open_plan  kitchen_area  balcony              locality_name  \
# ...

# %%
print('Диаграмма размаха времени продажи квартиры')
good_data.boxplot('days_exposition')
plt.ylabel('Время продажи квартиры')
plt.show()
# Out:
# Диаграмма размаха времени продажи квартиры

# %% [markdown]
# Значение по количеству дней в продаже свыше 250 лучше отсечь, т.к. это редкие квартиры с нестандартной планировкой и такие квартиры могут продаваться очень долго, для статистики они нам не нужны, т.к. сильно меняют сренее значение по сроку продажи квартир.

# %%
good_data = good_data.query('days_exposition < 250')

# %%
good_data['days_exposition'].agg(['mean','median'])
# Out:
# mean      80.930545
# median    60.000000
# Name: days_exposition, dtype: float64

# %%
good_data.plot(kind='hist',y='days_exposition',title='Распределение количества продаж по времени', bins=100, figsize=(10,5))

plt.xlabel('Сколько дней было размещено объявление (от публикации до снятия)')
plt.ylabel('Количество объявлений')
plt.show()

# %% [markdown]
# <a id=step_4.2.end></a>
# #### Вывод

# %% [markdown]
# В среднем продажа среднестатистичекой квартиры занимает 2-3 месяца в зависимотсти от сопутствующих факторов(площади, цены, удалённости от центра)

# %% [markdown]
# <a id='step_4.3'></a>

# %% [markdown]
# ##### Изучим, зависит ли цена от площади, числа комнат, удалённости от центра.

# %%
good_data['city_centers_nearest'] = good_data['city_centers_nearest']/1000
# Out:
# /opt/conda/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
(good_data
    
     .pivot_table(index='last_price', values=['total_area','rooms','city_centers_nearest'])
     .plot(style='o',grid=True, figsize=(12, 5), title='График зависимости цены от площади, числа комнат, удалённости от центра')
)
plt.xlabel('Цена на момент снятия с публикации')
plt.ylabel('Удалённость от центра\n Число комнат\n Площадь')
plt.show()

# %% [markdown]
# <a id='step_4.4'></a>

# %% [markdown]
# ##### Изучим зависимость цены от того, на каком этаже расположена квартира: первом, последнем или другом.

# %%
(good_data
     .pivot_table(index='group', values='last_price').sort_values(by='last_price', ascending=True)
     .plot(grid=True, figsize=(9, 5),linewidth=3, title='Зависимость цены от этажа расположения квартиры')
)
plt.xlabel('Этаж расположения квартиры')
plt.ylabel('Цена')
plt.show()

# %%
good_data.pivot_table(index='group',values='last_price',aggfunc='count').plot.pie(y='last_price', figsize=(7,7), label='', title='График количественного отношения распределения предложений в зависимости от этажа')
plt.show()

# %% [markdown]
# <a id=step_4.4.end></a>
# #### Вывод

# %% [markdown]
# Глядя на графики становится очевидно, что ценится любой другой этаж здания кроме первого и последнего, как по цене, так и по количеству предложений на рынке. А так же очевидна зависимость цены от удалённости от центра и площади квартиры, чем квартира больше и ближе к центру, тем цена выше. Чего нельзя однозначно сказать о количестве комнат, здесь график цены меняется не так значительно.

# %% [markdown]
# <a id='step_4.5'></a>

# %% [markdown]
# #####  Также изучим зависимость цены от даты размещения: дня недели, месяца и года.

# %%
(good_data
    
     .pivot_table(index='day_of_week_exposition', values=['last_price'])
     .plot(grid=True, figsize=(10, 5),linewidth=3,title='Зависимость цены от даты размещения')
)
plt.xlabel('День размещения')
plt.ylabel('Цена')

plt.show()

# %%
(good_data
    
     .pivot_table(index='month_exposition', values=['last_price'])
     .plot(grid=True, figsize=(10, 5),linewidth=3, title='Зависимость цены от месяца размещения')
)
plt.xlabel('Месяц размещения')
plt.ylabel('Цена')

plt.show()

# %%
(good_data
    
     .pivot_table(index='years_exposition', values=['last_price'])
     .plot(grid=True, figsize=(10, 5),linewidth=3,title='зависимость цены от года размещения')
     
)
plt.xlabel('Год размещения')
plt.ylabel('Цена')

plt.show()

# %% [markdown]
# <a id=step_4.5.end></a>
# #### Вывод

# %% [markdown]
# Удивительно, но объявления размещённые до четверга имеют большую цену, чем в другие дни недели. На графике помесячного размещения объявлений хорошо просматирваются два падения - это середина и конец года, в эти месяцы лучше квартиры не продавать, т.к. средняя стоимость ранка будет ниже чем в другие месяцы. По годовой тенденции наблюдается падение в стоимости жилья в 2015-2017 годах и  резкий взлёт стоимости начиная с 2018 года, что вызвано скорей всего большим спросом на рынке недвижимости.

# %% [markdown]
# <a id='step_4.6'></a>

# %% [markdown]
# #### Выберем 10 населённых пунктов с наибольшим числом объявлений.

# %%
data_top_10 = data.pivot_table(index='locality_name', values=['first_day_exposition'], aggfunc='count').sort_values(by='first_day_exposition', ascending=False).head(10)
data_top_10.columns=['number_of_ads']
data_top_10
# Out:
#                    number_of_ads
# locality_name
# санкт-петербург            15721
# посёлок мурино               556
# посёлок шушары               440
# всеволожск                   398
# пушкин                       369
# колпино                      338
# посёлок парголово            327
# гатчина                      307
# деревня кудрово              299
# выборг                       237

# %% [markdown]
# <a id=step_4.6.end></a>
# #### Вывод

# %% [markdown]
# Очевидный лидер по количеству объявлений это "Санкт_Петербург", остальные номинанты ТОП-10 расположены по области города примерно с равным количеством объявлений.

# %% [markdown]
# <a id='step_4.7'></a>

# %% [markdown]
# ##### Посчитаем среднюю цену квадратного метра в этих населённых пунктах.

# %%
data_top_10['cost_per_meter_mean'] = data.pivot_table(index='locality_name', values='price_per_square_meter', aggfunc='mean')
data_top_10_s=data_top_10.style.format({'cost_per_meter_mean':'{:.2f} ₽'})

# %%
data_top_10_s
# Out:
# <style  type="text/css" >
# </style><table id="T_897d6232_0df1_11eb_ae89_02420a39118d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >number_of_ads</th>        <th class="col_heading level0 col1" >cost_per_meter_mean</th>    </tr>    <tr>        <th class="index_name level0" >locality_name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_897d6232_0df1_11eb_ae89_02420a39118dlevel0_row0" class="row_heading level0 row0" >санкт-петербург</th>
#                         <td id="T_897d6232_0df1_11eb_ae89_02420a39118drow0_col0" class="data row0 col0" >15721</td>
#                         <td id="T_897d6232_0df1_11eb_ae89_02420a39118drow0_col1" class="data row0 col1" >114848.57 ₽</td>
#             </tr>
#             <tr>
# ...

# %% [markdown]
# <a id=step_4.7.end></a>
# #### Вывод

# %% [markdown]
# По средней стоимости за квадратный метр жилья можно сказать, что низкое количество объявлений не сильно влияет на цену кв.метра, так например Пушкин и посёлок Парголово имеют практически ту же цену в 100 т.р. за кв. метр как и жил.площадь в Санкт-Петербурге.

# %% [markdown]
# <a id='step_4.8'></a>

# %% [markdown]
# #####  Выделим среди них населённые пункты с самой высокой и низкой стоимостью жилья.

# %%
(data_top_10_s
 .highlight_max(color='yellowgreen', subset='cost_per_meter_mean')
 .highlight_min(color='coral', subset='cost_per_meter_mean')
)
# Out:
# <style  type="text/css" >
#     #T_89867110_0df1_11eb_ae89_02420a39118drow0_col1 {
#             background-color:  yellowgreen;
#             : ;
#         }    #T_89867110_0df1_11eb_ae89_02420a39118drow9_col1 {
#             : ;
#             background-color:  coral;
#         }</style><table id="T_89867110_0df1_11eb_ae89_02420a39118d" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >number_of_ads</th>        <th class="col_heading level0 col1" >cost_per_meter_mean</th>    </tr>    <tr>        <th class="index_name level0" >locality_name</th>        <th class="blank" ></th>        <th class="blank" ></th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89867110_0df1_11eb_ae89_02420a39118dlevel0_row0" class="row_heading level0 row0" >санкт-петербург</th>
#                         <td id="T_89867110_0df1_11eb_ae89_02420a39118drow0_col0" class="data row0 col0" >15721</td>
# ...

# %%
data_top_10.pivot_table(index='locality_name',values='cost_per_meter_mean').plot.pie(y='cost_per_meter_mean', figsize=(7,7), legend=False, label='', title='Населённые пункты с самой высокой и низкой стоимостью жилья')
plt.show()

# %% [markdown]
# <a id=step_4.8.end></a>
# #### Вывод

# %% [markdown]
#  Самая низкая стоимость жилья из нашей ТОП-10 расположена в Выборге и Всеволожске, а на первом месте расположился Санкт-Петребург, с незначительным отрывом от Пушкина

# %% [markdown]
# <a id=step_4.8.1></a>

# %% [markdown]
# #### Изучим предложения квартир: выделим квартиры в Санкт-Петербурге ('locality_name'). Выясним, какая область входит в центр.

# %%
local_spb = data.loc[data['locality_name'] == 'санкт-петербург']

# %%
local_spb['city_centers_nearest'].isna().sum()
# Out:
# 61

# %%
local_spb=local_spb.dropna(subset=['city_centers_nearest'])

# %% [markdown]
# Создадим столбец с расстоянием до центра в километрах и округлим их до целых значений.

# %%
local_spb['city_centers_nearest_km']=(local_spb['city_centers_nearest']/1000).round().astype(int)

# %%
local_spb['city_centers_nearest_km'].describe()
# Out:
# count    15660.000000
# mean        11.596041
# std          4.863594
# min          0.000000
# 25%          8.000000
# 50%         12.000000
# 75%         15.000000
# max         29.000000
# Name: city_centers_nearest_km, dtype: float64

# %%
print('Диаграмма размаха удалённости от центра')
local_spb.boxplot('city_centers_nearest_km')

plt.ylabel('Километры от центра города')
plt.show()
# Out:
# Диаграмма размаха удалённости от центра

# %%
local_spb = local_spb.loc[local_spb['city_centers_nearest_km'] < 24]

# %% [markdown]
# <a id=step_4.8.1.end></a>
# #### Вывод

# %% [markdown]
# Очевидно, что город Санкт-Петрбург очень большой, но даже для него расстояние больше 24 км от центра не может считаться центром города, по-этому мы отсекли мешающие статисткие и анализу данные

# %% [markdown]
# <a id='step_4.9'></a>

# %% [markdown]
# ##### Посчитаем среднюю цену для каждого километра

# %%
local_spb.head()
# Out:
#    total_images  last_price  total_area first_day_exposition  rooms  \
# 0            20  13000000.0       108.0           2019-03-07      3
# 2            10   5196000.0        56.0           2015-08-20      2
# 3             0  64900000.0       159.0           2015-07-24      3
# 4             2  10000000.0       100.0           2018-06-19      2
# 7             5   7915000.0        71.6           2019-04-18      2
#
#    ceiling_height  floors_total  living_area  floor  is_apartment  studio  \
# 0            2.70          16.0         51.0      8         False   False
# 2            2.72           5.0         34.3      4         False   False
# 3            2.72          14.0          NaN      9         False   False
# 4            3.03          14.0         32.0     13         False   False
# 7            2.72          24.0          NaN     22         False   False
#
#    open_plan  kitchen_area  balcony    locality_name  airports_nearest  \
# ...

# %%
mean_cost_per_km = local_spb['last_price'].sum()/local_spb['city_centers_nearest_km'].sum()
print('Средняя цена для каждого километра составляет {:.0f} ₽'.format(mean_cost_per_km))
# Out:
# Средняя цена для каждого километра составляет 701890 ₽

# %% [markdown]
# ###### Построим график: он будет показывать, как цена зависит от удалённости от центра. А так же определим границу центральной зоны.

# %%
local_spb.pivot_table(index='city_centers_nearest_km', values='last_price', aggfunc='mean').plot(figsize=(10,5), grid=True, linewidth=3, title='График зависимости цены от удалённости от центра')
plt.xlabel('Километры от центра города')
plt.ylabel('Средняя стоимость предложения')
plt.show()

# %% [markdown]
# Очевидно, что падение цены на графике сильно изменилось при достижении значения в 9-10 км, это говорит нам, что центральным районом можно считать все квартиры в удалении от центра не более чем на 10 км.

# %% [markdown]
# <a id='step_4.10'></a>

# %% [markdown]
# ##### Выделим сегмент квартир в центре. Проанализируем эту территорию и изучим следующие параметры: площадь, цена, число комнат, высота потолков.

# %%
local_spb_centre = local_spb.loc[local_spb['city_centers_nearest_km']<10]

# %%
analysis_1=local_spb_centre[['locality_name','total_area','last_price','rooms','ceiling_height']].reset_index(drop=True)

# %%
analysis_1.corr()
# Out:
#                 total_area  last_price     rooms  ceiling_height
# total_area        1.000000    0.643813  0.750790        0.314814
# last_price        0.643813    1.000000  0.351014        0.181108
# rooms             0.750790    0.351014  1.000000        0.273154
# ceiling_height    0.314814    0.181108  0.273154        1.000000

# %%
analysis_1.describe()
# Out:
#         total_area    last_price        rooms  ceiling_height
# count  4715.000000  4.715000e+03  4715.000000     4715.000000
# mean     86.437506  1.327110e+07     2.671050        2.917637
# std      56.839196  2.224446e+07     1.393877        0.335133
# min      12.000000  1.219000e+04     0.000000        2.000000
# 25%      51.000000  5.954074e+06     2.000000        2.720000
# 50%      72.600000  8.500000e+06     3.000000        2.750000
# 75%     102.000000  1.307500e+07     3.000000        3.070000
# max     900.000000  7.630000e+08    19.000000        6.000000

# %%
pd.plotting.scatter_matrix(analysis_1, figsize=(10, 10)) 

plt.show()

# %% [markdown]
# <a id=step_4.10.end></a>
# #### Вывод

# %% [markdown]
# Из приведённых графиков становится очевидно, что основной сегмент квартир в центре города занимают 2-3 комнатные квартиры, площадью до 73 кв.метров, с потолками 2,75 средней ценой до 8,5 млн. рублей.

# %% [markdown]
# <a id='step_4.11'></a>

# %% [markdown]
#  ##### Выделим факторы, которые влияют на стоимость квартиры (число комнат, этаж, удалённость от центра, дата размещения объявления)

# %%
analysis_2=local_spb_centre[['last_price','rooms','floor','city_centers_nearest_km','first_day_exposition']]
pd.plotting.scatter_matrix(analysis_2, figsize=(10, 10))
plt.show()

# %% [markdown]
# Определим зависимость цены от даты размещения объявления при помощи графика

# %%
local_spb_centre.pivot_table(index=['day_of_week_exposition','month_exposition','years_exposition'], values='last_price', aggfunc='mean').sort_values(by='years_exposition').plot(grid=True,linewidth=3, alpha=0.7, label='2015',figsize=(15,5), title='Зависимость цены от даты размещения объявления')

plt.xlabel('Дата размещения объявления')
plt.ylabel('Цена')
plt.show()

# %% [markdown]
# <a id=step_4_end><a>

# %% [markdown]
# ### Вывод

# %% [markdown]
# В целом из графиков можно сделать вывод о том, что цена объявелния квартир в центре города не зависит от удалённости от центра, зависимость цены менятся только от площади и количесва комнат, так же ценятся квартиры в центре города не выше 10 этажа. Изучив зависимость этажности и удаления от центра можно заметить, что чем дальше от центра города, тем выше этаж квартиры в объявлении. А вот по дате размещения объявления заметен основной пик в стоимости жилья в 2015-2016 годах с плавным снижением к 2019 году, в то время как по остальным предложениям стоимость жилья за пределами центра активно растёт начиная с 2017 года.

# %% [markdown]
# <a id=step_5></a>
# ### Часть 5. Общий вывод

# %% [markdown]
#   Подводя итог проделанной работы по подготовке данных к анализу мы столкнулись с большим количеством пропусков в колонках, которые могут влиять как на среднюю цену предлодения квартир на рынке, так и на анализ выделенных групп в частности. Тем не менее какие-то данные мы заполнили средним значением дабы не терять основной массив статистичесих данны, а некоторые данные оставили без изменений с пропущенными значениями. По результату проделанной работы по обработке и анализу недостающих и "битых" данных, несомненно надо обратить внимание коллег по подготовке и сбору данных на заполняемость ячеек, либо на крректность выгрузки данных из программы. Ошибок связанных с человеческим фактором(опечаток и пр.) довольно мало, что сильно облегчило труд по предобработке материала для анализа.
#
#   После избавления нашей базы от 'мусорных' и выбивающихся значений мы выполнили такие операции как подсчёт средней стоимости квадратного метра жилья, стоимость каждого километра удаления от центра, выделили сегмент квартир расположенных в центре и проанализировали их параметры, а так же вывели статистику по скорости продажи объявления с даты его размещения, факторы влияющие на это и проанализировали статистику продаж в зависимости от периода размещения объявления.
#
#   Для большей наглядности при анализе использовались графики, из которых лего можно сделать вывод о том, что лидером по размещению объявлений о продаже недвижимости является "Санкт-Петербург", несмотря на это средняя цена квадратного метра приблизительно такая же как и по области. Тенденция рынка такова, что начиная с 2017 года активно растёт спрос на жильё за пределами центра Петербурга, при этом люди в основной своей массе стараются найти предложения квартир на любом этаже за исключением первого и последнего, за частую это высотные здания и новостройки.  В центре же города ситуция обратная, застройки практически никакой не ведётся, этажность домов не большая и продажа квартир ведётся из старого фонда, что и отражается на снижающемся спросе начиная с 2016 года.
#
#   В сухом остатке в большинстве случаев покупки жилья люди выбирают 1-2 комнатные квартиры в высотной новостройке по периметру города Санкт-Петребург, с средней стоимостью в 100 т.р. за кв.метр. и высотой потолков 2,75. Таким образом можно сделать вывод о том, что количество таких домов и соответственно предложений будет расти в след за ценой в отличии от цен на жильё расположенного по центру исторического района города в невысоких домах из старого фонда.

# %% [markdown]
# #### <a href='#Up_start'><k>Вернуться к оглавлению</k></a>
